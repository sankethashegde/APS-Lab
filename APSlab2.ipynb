# %% [markdown]
# <a href="https://colab.research.google.com/github/sankethashegde/APS-Lab/blob/main/APSlab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"In a group of people, in what is the probability that atleast two people share the same birthday"

"""import random
import pandas as pd
import matplotlib.pyplot as plt
probabilities = []
people=range(2,51)
no_of_trails=1000
for n in people:
  birthday_on_same_day=0
  for i in range(no_of_trails):
    birthday = [random.randint(1, 365) for i in range(n)]
    #birthday=[random.randint(1,365) for i in range(2,51)]
    if len(birthday) != len(set(birthday)):
       birthday_on_same_day= birthday_on_same_day+1
  probability=birthday_on_same_day/no_of_trails
#print("The number of 2 or more people having same birthday",probability)
  probabilities.append(probability)
plt.plot(people, probabilities, marker='o')
plt.plot(people, probabilities, marker='o', markersize=3)
plt.xlabel("Number of People")
plt.ylabel("Probability")
plt.title("Birthday Problem")"""


import pandas as pd
import matplotlib.pyplot as plt
days = 365
people_l = []
probability_l= []
for people in range(1, 31):
    probabilityofdifferent = 1
    for i in range(people):
        probabilityofdifferent *= (days - i) / days
    probabilityofsame = 1 - probabilityofdifferent
    people_l.append(people)
    probability_l.append(probabilityofsame)
df = pd.DataFrame({
    "People": people_l,
    "Probability": probability_l
})
print(df)
plt.figure(figsize=(10,7))
plt.plot(
    df["People"],
    df["Probability"],
    marker=".",
    color="pink",
    linewidth=1
)
plt.xlabel("Number of People")
plt.ylabel("Probability ")
plt.title("Birthday Problem")
plt.xticks(range(1,31))
plt.show()
# Out:
#     People  Probability
# 0        1     0.000000
# 1        2     0.002740
# 2        3     0.008204
# 3        4     0.016356
# 4        5     0.027136
# 5        6     0.040462
# 6        7     0.056236
# 7        8     0.074335
# 8        9     0.094624
# 9       10     0.116948
# 10      11     0.141141
# 11      12     0.167025
# 12      13     0.194410
# 13      14     0.223103
# 14      15     0.252901
# 15      16     0.283604
# 16      17     0.315008
# 17      18     0.346911
# 18      19     0.379119
# 19      20     0.411438
# 20      21     0.443688
# 21      22     0.475695
# 22      23     0.507297
# 23      24     0.538344
# 24      25     0.568700
# 25      26     0.598241
# 26      27     0.626859
# 27      28     0.654461
# 28      29     0.680969
# 29      30     0.706316
